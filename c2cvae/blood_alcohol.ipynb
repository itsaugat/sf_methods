# %%
from numpy.core.numeric import True_
import sys
import os
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torch.optim as optim
from tqdm import tqdm
from torch.utils.data import Dataset, DataLoader, TensorDataset
from sklearn.linear_model import LogisticRegression
#from matplotlib import pyplot as plt
#from PIL import Image, ImageDraw
#from IPython import display
#from torchvision import transforms

# %%
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
device
# Out:
# device(type='mps')

# %%
data = 'blood_alcohol'
df = pd.read_csv('../datasets/'+data+'_sc.csv')

# %%
df.head()
# Out:
#      gender     meal  units_consumed    weight  duration  class
# 0  0.829965  0.64502        0.272727  0.513158  0.691729      0
# 1  0.829965  0.64502        0.363636  0.447368  0.601504      1
# 2  0.829965  0.64502        0.363636  0.460526  0.330827      1
# 3  0.829965  0.68598        0.272727  0.565789  0.669173      0
# 4  0.829965  0.64502        0.636364  0.473684  0.413534      1

# %%
target = 'class'
y = df[target].values
del df[target]
x = df.values

# %%
x.shape[1]
# Out:
# 5

# %%
y
# Out:
# array([0, 1, 1, ..., 1, 0, 1])

# %%
# train the classifier to be explained -> Logistic Regression Model (can be replaced with a MLP)
# clf = LogisticRegression(max_iter=1000, fit_intercept=False, class_weight='balanced')
# clf.fit(x, y)

# %%
# Convert numpy arrays to PyTorch tensors
x_train_tensor = torch.FloatTensor(x).to(device)
y_train_tensor = torch.LongTensor(y).to(device)

# %%
# Create a TensorDataset
dataset = TensorDataset(x_train_tensor, y_train_tensor)

# %%
# Create a DataLoader
dl_batch_size = 32  # Set your desired batch size
train_dataloader = DataLoader(dataset, batch_size=dl_batch_size, shuffle=True)

# %%
num_epochs = 500

# %%
latent_dims = 4
# capacity = no. of hidden neurons in a layer
capacity = 6
variational_beta = 1

# %%
class Encoder(nn.Module):
    def __init__(self, input_dim):
        super(Encoder, self).__init__()
        c = capacity
        self.fc1 = nn.Linear(in_features=input_dim, out_features=c*2)
        self.fc2 = nn.Linear(in_features=c*2, out_features=latent_dims)
        self.fc3 = nn.Linear(in_features=c*2, out_features=latent_dims)
            
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x_mu = self.fc2(x)
        x_logvar = self.fc3(x)
        return x_mu, x_logvar

class Decoder(nn.Module):
    def __init__(self, output_dim):
        super(Decoder, self).__init__()
        c = capacity
        self.fc = nn.Linear(in_features=latent_dims, out_features=c*2)
        self.fc_output = nn.Linear(in_features=c*2, out_features=output_dim)
            
    def forward(self, x):
        x = F.relu(self.fc(x))
        x_recon = self.fc_output(x)
        return x_recon

class VariationalAutoencoder(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(VariationalAutoencoder, self).__init__()
        self.encoder = Encoder(input_dim)
        self.decoder = Decoder(output_dim)
    
    def forward(self, x):
        latent_mu, latent_logvar = self.encoder(x)
        latent = self.latent_sample(latent_mu, latent_logvar)
        x_recon = self.decoder(latent)
        return x_recon, latent_mu, latent_logvar
    
    def latent_sample(self, mu, logvar):
        if self.training:
            std = logvar.mul(0.5).exp_()
            eps = torch.empty_like(std).normal_()
            return eps.mul(std).add_(mu)
        else:
            return mu
    
def vae_loss(recon_x, x, mu, logvar):
    recon_loss = F.mse_loss(recon_x, x, reduction='sum')  # Mean Squared Error loss for tabular data
    kldivergence = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    
    return recon_loss + variational_beta * kldivergence

# %%
# Train VAE
print(device)
vae = VariationalAutoencoder(input_dim=x.shape[1], output_dim=x.shape[1])
vae = vae.to(device)

optimizer = torch.optim.Adam(params=vae.parameters(), lr=1e-3, weight_decay=1e-5)

train_loss_avg = []

train_vae = True

if train_vae == False:   
    filename = 'blood_alcohol_vae.pth'
    vae.load_state_dict(torch.load(filename))
    vae.eval()
    print('done')

else:
    for epoch in range(num_epochs):
        vae.train()
        train_loss_avg.append(0)
        num_batches = 0

        for x_batch, _ in train_dataloader:

            x_batch = x_batch.to(device)

            # Forward pass
            x_recon, latent_mu, latent_logvar = vae(x_batch)
            loss = vae_loss(x_recon, x_batch, latent_mu, latent_logvar)

            # Backward pass and optimization
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            train_loss_avg[-1] += loss.item()
            num_batches += 1

        train_loss_avg[-1] /= num_batches
        print('Epoch [%d / %d] average loss: %f' % (epoch + 1, num_epochs, train_loss_avg[-1]))

    # Save the model
    model_name = data+'_vae.pth'
    torch.save(vae.state_dict(), model_name)
# Out:
# mps
# Epoch [1 / 500] average loss: 42.142004
# Epoch [2 / 500] average loss: 19.496738
# Epoch [3 / 500] average loss: 11.248014
# Epoch [4 / 500] average loss: 7.117998
# Epoch [5 / 500] average loss: 5.241925
# Epoch [6 / 500] average loss: 4.707400
# Epoch [7 / 500] average loss: 4.303568
# Epoch [8 / 500] average loss: 4.105686
# Epoch [9 / 500] average loss: 3.974809
# Epoch [10 / 500] average loss: 3.836573
# Epoch [11 / 500] average loss: 3.778034
# Epoch [12 / 500] average loss: 3.729431
# Epoch [13 / 500] average loss: 3.721640
# Epoch [14 / 500] average loss: 3.647621
# Epoch [15 / 500] average loss: 3.636164
# Epoch [16 / 500] average loss: 3.608647
# Epoch [17 / 500] average loss: 3.624574
# Epoch [18 / 500] average loss: 3.583366
# Epoch [19 / 500] average loss: 3.583718
# Epoch [20 / 500] average loss: 3.574937
# Epoch [21 / 500] average loss: 3.544930
# Epoch [22 / 500] average loss: 3.561048
# Epoch [23 / 500] average loss: 3.568011
# Epoch [24 / 500] average loss: 3.536254
# Epoch [25 / 500] average loss: 3.530812
# Epoch [26 / 500] average loss: 3.517309
# Epoch [27 / 500] average loss: 3.521862
# Epoch [28 / 500] average loss: 3.513936
# Epoch [29 / 500] average loss: 3.514508
# Epoch [30 / 500] average loss: 3.515680
# Epoch [31 / 500] average loss: 3.515757
# Epoch [32 / 500] average loss: 3.505566
# Epoch [33 / 500] average loss: 3.496088
# Epoch [34 / 500] average loss: 3.492911
# Epoch [35 / 500] average loss: 3.500532
# Epoch [36 / 500] average loss: 3.501659
# Epoch [37 / 500] average loss: 3.499036
# Epoch [38 / 500] average loss: 3.499304
# Epoch [39 / 500] average loss: 3.502078
# Epoch [40 / 500] average loss: 3.494787
# Epoch [41 / 500] average loss: 3.497525
# Epoch [42 / 500] average loss: 3.499072
# Epoch [43 / 500] average loss: 3.502876
# Epoch [44 / 500] average loss: 3.504327
# Epoch [45 / 500] average loss: 3.479250
# Epoch [46 / 500] average loss: 3.499727
# Epoch [47 / 500] average loss: 3.478770
# Epoch [48 / 500] average loss: 3.503096
# Epoch [49 / 500] average loss: 3.491905
# Epoch [50 / 500] average loss: 3.497081
# Epoch [51 / 500] average loss: 3.500969
# Epoch [52 / 500] average loss: 3.493339
# Epoch [53 / 500] average loss: 3.491450
# Epoch [54 / 500] average loss: 3.492346
# Epoch [55 / 500] average loss: 3.488267
# Epoch [56 / 500] average loss: 3.496019
# Epoch [57 / 500] average loss: 3.493455
# Epoch [58 / 500] average loss: 3.488792
# Epoch [59 / 500] average loss: 3.496581
# Epoch [60 / 500] average loss: 3.489026
# Epoch [61 / 500] average loss: 3.490310
# Epoch [62 / 500] average loss: 3.484010
# Epoch [63 / 500] average loss: 3.490424
# Epoch [64 / 500] average loss: 3.497443
# Epoch [65 / 500] average loss: 3.486154
# Epoch [66 / 500] average loss: 3.487141
# Epoch [67 / 500] average loss: 3.485922
# Epoch [68 / 500] average loss: 3.481470
# Epoch [69 / 500] average loss: 3.481458
# Epoch [70 / 500] average loss: 3.486227
# Epoch [71 / 500] average loss: 3.490081
# Epoch [72 / 500] average loss: 3.489840
# Epoch [73 / 500] average loss: 3.493516
# Epoch [74 / 500] average loss: 3.492543
# Epoch [75 / 500] average loss: 3.492941
# Epoch [76 / 500] average loss: 3.490157
# Epoch [77 / 500] average loss: 3.484421
# Epoch [78 / 500] average loss: 3.481754
# Epoch [79 / 500] average loss: 3.491640
# Epoch [80 / 500] average loss: 3.496517
# Epoch [81 / 500] average loss: 3.485903
# Epoch [82 / 500] average loss: 3.486260
# Epoch [83 / 500] average loss: 3.480386
# Epoch [84 / 500] average loss: 3.482388
# Epoch [85 / 500] average loss: 3.487841
# Epoch [86 / 500] average loss: 3.490957
# Epoch [87 / 500] average loss: 3.487100
# Epoch [88 / 500] average loss: 3.487805
# Epoch [89 / 500] average loss: 3.486359
# Epoch [90 / 500] average loss: 3.491780
# Epoch [91 / 500] average loss: 3.484406
# Epoch [92 / 500] average loss: 3.487274
# Epoch [93 / 500] average loss: 3.486065
# Epoch [94 / 500] average loss: 3.496493
# Epoch [95 / 500] average loss: 3.476496
# Epoch [96 / 500] average loss: 3.483588
# Epoch [97 / 500] average loss: 3.500134
# Epoch [98 / 500] average loss: 3.489906
# Epoch [99 / 500] average loss: 3.492603
# Epoch [100 / 500] average loss: 3.482767
# Epoch [101 / 500] average loss: 3.491644
# Epoch [102 / 500] average loss: 3.486351
# Epoch [103 / 500] average loss: 3.486264
# Epoch [104 / 500] average loss: 3.483470
# Epoch [105 / 500] average loss: 3.488966
# Epoch [106 / 500] average loss: 3.486432
# Epoch [107 / 500] average loss: 3.487464
# Epoch [108 / 500] average loss: 3.490254
# Epoch [109 / 500] average loss: 3.485429
# Epoch [110 / 500] average loss: 3.484849
# Epoch [111 / 500] average loss: 3.484888
# Epoch [112 / 500] average loss: 3.488543
# Epoch [113 / 500] average loss: 3.485654
# Epoch [114 / 500] average loss: 3.483731
# Epoch [115 / 500] average loss: 3.488639
# Epoch [116 / 500] average loss: 3.483167
# Epoch [117 / 500] average loss: 3.493391
# Epoch [118 / 500] average loss: 3.481138
# Epoch [119 / 500] average loss: 3.487300
# Epoch [120 / 500] average loss: 3.487897
# Epoch [121 / 500] average loss: 3.493442
# Epoch [122 / 500] average loss: 3.481738
# Epoch [123 / 500] average loss: 3.484168
# Epoch [124 / 500] average loss: 3.487255
# Epoch [125 / 500] average loss: 3.483576
# Epoch [126 / 500] average loss: 3.480437
# Epoch [127 / 500] average loss: 3.480230
# Epoch [128 / 500] average loss: 3.487647
# Epoch [129 / 500] average loss: 3.483325
# Epoch [130 / 500] average loss: 3.479035
# Epoch [131 / 500] average loss: 3.489140
# Epoch [132 / 500] average loss: 3.486245
# Epoch [133 / 500] average loss: 3.481065
# Epoch [134 / 500] average loss: 3.481667
# Epoch [135 / 500] average loss: 3.484335
# Epoch [136 / 500] average loss: 3.482382
# Epoch [137 / 500] average loss: 3.484930
# Epoch [138 / 500] average loss: 3.488250
# Epoch [139 / 500] average loss: 3.484178
# Epoch [140 / 500] average loss: 3.485075
# Epoch [141 / 500] average loss: 3.485944
# Epoch [142 / 500] average loss: 3.482434
# Epoch [143 / 500] average loss: 3.476705
# Epoch [144 / 500] average loss: 3.483166
# Epoch [145 / 500] average loss: 3.490281
# Epoch [146 / 500] average loss: 3.489395
# Epoch [147 / 500] average loss: 3.481146
# Epoch [148 / 500] average loss: 3.486823
# Epoch [149 / 500] average loss: 3.483442
# Epoch [150 / 500] average loss: 3.490134
# Epoch [151 / 500] average loss: 3.490435
# Epoch [152 / 500] average loss: 3.485021
# Epoch [153 / 500] average loss: 3.485736
# Epoch [154 / 500] average loss: 3.483056
# Epoch [155 / 500] average loss: 3.486744
# Epoch [156 / 500] average loss: 3.487139
# Epoch [157 / 500] average loss: 3.480027
# Epoch [158 / 500] average loss: 3.483213
# Epoch [159 / 500] average loss: 3.488659
# Epoch [160 / 500] average loss: 3.479617
# Epoch [161 / 500] average loss: 3.481740
# Epoch [162 / 500] average loss: 3.482511
# Epoch [163 / 500] average loss: 3.487697
# Epoch [164 / 500] average loss: 3.487220
# Epoch [165 / 500] average loss: 3.485940
# Epoch [166 / 500] average loss: 3.484784
# Epoch [167 / 500] average loss: 3.484368
# Epoch [168 / 500] average loss: 3.484592
# Epoch [169 / 500] average loss: 3.482900
# Epoch [170 / 500] average loss: 3.481965
# Epoch [171 / 500] average loss: 3.486934
# Epoch [172 / 500] average loss: 3.484380
# Epoch [173 / 500] average loss: 3.483474
# Epoch [174 / 500] average loss: 3.484641
# Epoch [175 / 500] average loss: 3.482718
# Epoch [176 / 500] average loss: 3.483939
# Epoch [177 / 500] average loss: 3.491827
# Epoch [178 / 500] average loss: 3.487055
# Epoch [179 / 500] average loss: 3.480957
# Epoch [180 / 500] average loss: 3.485114
# Epoch [181 / 500] average loss: 3.488045
# Epoch [182 / 500] average loss: 3.482062
# Epoch [183 / 500] average loss: 3.485719
# Epoch [184 / 500] average loss: 3.480705
# Epoch [185 / 500] average loss: 3.486914
# Epoch [186 / 500] average loss: 3.479864
# Epoch [187 / 500] average loss: 3.492651
# Epoch [188 / 500] average loss: 3.483362
# Epoch [189 / 500] average loss: 3.485633
# Epoch [190 / 500] average loss: 3.491026
# Epoch [191 / 500] average loss: 3.486701
# Epoch [192 / 500] average loss: 3.480801
# Epoch [193 / 500] average loss: 3.491144
# Epoch [194 / 500] average loss: 3.479739
# Epoch [195 / 500] average loss: 3.488188
# Epoch [196 / 500] average loss: 3.482885
# Epoch [197 / 500] average loss: 3.482884
# Epoch [198 / 500] average loss: 3.481885
# Epoch [199 / 500] average loss: 3.482641
# Epoch [200 / 500] average loss: 3.484734
# Epoch [201 / 500] average loss: 3.483311
# Epoch [202 / 500] average loss: 3.482296
# Epoch [203 / 500] average loss: 3.482704
# Epoch [204 / 500] average loss: 3.482290
# Epoch [205 / 500] average loss: 3.485061
# Epoch [206 / 500] average loss: 3.487126
# Epoch [207 / 500] average loss: 3.483248
# Epoch [208 / 500] average loss: 3.485379
# Epoch [209 / 500] average loss: 3.485599
# Epoch [210 / 500] average loss: 3.486572
# Epoch [211 / 500] average loss: 3.479945
# Epoch [212 / 500] average loss: 3.487856
# Epoch [213 / 500] average loss: 3.480717
# Epoch [214 / 500] average loss: 3.484770
# Epoch [215 / 500] average loss: 3.476067
# Epoch [216 / 500] average loss: 3.483261
# Epoch [217 / 500] average loss: 3.483432
# Epoch [218 / 500] average loss: 3.489142
# Epoch [219 / 500] average loss: 3.487213
# Epoch [220 / 500] average loss: 3.483817
# Epoch [221 / 500] average loss: 3.487183
# Epoch [222 / 500] average loss: 3.481345
# Epoch [223 / 500] average loss: 3.477669
# Epoch [224 / 500] average loss: 3.483326
# Epoch [225 / 500] average loss: 3.482565
# Epoch [226 / 500] average loss: 3.487175
# Epoch [227 / 500] average loss: 3.492199
# Epoch [228 / 500] average loss: 3.483046
# Epoch [229 / 500] average loss: 3.481361
# Epoch [230 / 500] average loss: 3.487949
# Epoch [231 / 500] average loss: 3.488289
# Epoch [232 / 500] average loss: 3.488094
# Epoch [233 / 500] average loss: 3.484002
# Epoch [234 / 500] average loss: 3.480802
# Epoch [235 / 500] average loss: 3.482002
# Epoch [236 / 500] average loss: 3.487564
# Epoch [237 / 500] average loss: 3.484417
# Epoch [238 / 500] average loss: 3.483995
# Epoch [239 / 500] average loss: 3.486990
# Epoch [240 / 500] average loss: 3.476590
# Epoch [241 / 500] average loss: 3.480159
# Epoch [242 / 500] average loss: 3.484179
# Epoch [243 / 500] average loss: 3.480544
# Epoch [244 / 500] average loss: 3.486183
# Epoch [245 / 500] average loss: 3.483162
# Epoch [246 / 500] average loss: 3.485755
# Epoch [247 / 500] average loss: 3.485859
# Epoch [248 / 500] average loss: 3.485406
# Epoch [249 / 500] average loss: 3.485168
# Epoch [250 / 500] average loss: 3.482969
# Epoch [251 / 500] average loss: 3.484129
# Epoch [252 / 500] average loss: 3.481940
# Epoch [253 / 500] average loss: 3.487631
# Epoch [254 / 500] average loss: 3.485720
# Epoch [255 / 500] average loss: 3.487014
# Epoch [256 / 500] average loss: 3.483309
# Epoch [257 / 500] average loss: 3.482857
# Epoch [258 / 500] average loss: 3.481372
# Epoch [259 / 500] average loss: 3.489548
# Epoch [260 / 500] average loss: 3.483178
# Epoch [261 / 500] average loss: 3.486638
# Epoch [262 / 500] average loss: 3.477001
# Epoch [263 / 500] average loss: 3.487375
# Epoch [264 / 500] average loss: 3.484116
# Epoch [265 / 500] average loss: 3.479258
# Epoch [266 / 500] average loss: 3.484081
# Epoch [267 / 500] average loss: 3.486611
# Epoch [268 / 500] average loss: 3.484742
# Epoch [269 / 500] average loss: 3.484203
# Epoch [270 / 500] average loss: 3.483316
# Epoch [271 / 500] average loss: 3.482910
# Epoch [272 / 500] average loss: 3.490133
# Epoch [273 / 500] average loss: 3.486267
# Epoch [274 / 500] average loss: 3.479578
# Epoch [275 / 500] average loss: 3.484692
# Epoch [276 / 500] average loss: 3.489153
# Epoch [277 / 500] average loss: 3.482892
# Epoch [278 / 500] average loss: 3.484329
# Epoch [279 / 500] average loss: 3.484095
# Epoch [280 / 500] average loss: 3.484763
# Epoch [281 / 500] average loss: 3.486420
# Epoch [282 / 500] average loss: 3.488567
# Epoch [283 / 500] average loss: 3.481863
# Epoch [284 / 500] average loss: 3.482824
# Epoch [285 / 500] average loss: 3.489191
# Epoch [286 / 500] average loss: 3.482222
# Epoch [287 / 500] average loss: 3.488122
# Epoch [288 / 500] average loss: 3.486532
# Epoch [289 / 500] average loss: 3.483059
# Epoch [290 / 500] average loss: 3.487799
# Epoch [291 / 500] average loss: 3.484524
# Epoch [292 / 500] average loss: 3.492015
# Epoch [293 / 500] average loss: 3.485382
# Epoch [294 / 500] average loss: 3.482000
# Epoch [295 / 500] average loss: 3.482516
# Epoch [296 / 500] average loss: 3.481748
# Epoch [297 / 500] average loss: 3.483828
# Epoch [298 / 500] average loss: 3.483007
# Epoch [299 / 500] average loss: 3.483299
# Epoch [300 / 500] average loss: 3.485587
# Epoch [301 / 500] average loss: 3.485898
# Epoch [302 / 500] average loss: 3.485049
# Epoch [303 / 500] average loss: 3.488037
# Epoch [304 / 500] average loss: 3.479242
# Epoch [305 / 500] average loss: 3.482999
# Epoch [306 / 500] average loss: 3.487509
# Epoch [307 / 500] average loss: 3.487118
# Epoch [308 / 500] average loss: 3.483787
# Epoch [309 / 500] average loss: 3.483209
# Epoch [310 / 500] average loss: 3.486720
# Epoch [311 / 500] average loss: 3.482191
# Epoch [312 / 500] average loss: 3.485229
# Epoch [313 / 500] average loss: 3.484068
# Epoch [314 / 500] average loss: 3.484376
# Epoch [315 / 500] average loss: 3.485224
# Epoch [316 / 500] average loss: 3.486568
# Epoch [317 / 500] average loss: 3.483201
# Epoch [318 / 500] average loss: 3.487348
# Epoch [319 / 500] average loss: 3.478003
# Epoch [320 / 500] average loss: 3.479595
# Epoch [321 / 500] average loss: 3.485969
# Epoch [322 / 500] average loss: 3.484402
# Epoch [323 / 500] average loss: 3.481604
# Epoch [324 / 500] average loss: 3.480332
# Epoch [325 / 500] average loss: 3.485969
# Epoch [326 / 500] average loss: 3.485957
# Epoch [327 / 500] average loss: 3.488078
# Epoch [328 / 500] average loss: 3.482373
# Epoch [329 / 500] average loss: 3.475236
# Epoch [330 / 500] average loss: 3.484755
# Epoch [331 / 500] average loss: 3.487830
# Epoch [332 / 500] average loss: 3.479662
# Epoch [333 / 500] average loss: 3.485307
# Epoch [334 / 500] average loss: 3.483390
# Epoch [335 / 500] average loss: 3.483766
# Epoch [336 / 500] average loss: 3.481457
# Epoch [337 / 500] average loss: 3.483964
# Epoch [338 / 500] average loss: 3.484537
# Epoch [339 / 500] average loss: 3.481960
# Epoch [340 / 500] average loss: 3.482582
# Epoch [341 / 500] average loss: 3.489251
# Epoch [342 / 500] average loss: 3.484757
# Epoch [343 / 500] average loss: 3.483066
# Epoch [344 / 500] average loss: 3.483231
# Epoch [345 / 500] average loss: 3.482310
# Epoch [346 / 500] average loss: 3.486541
# Epoch [347 / 500] average loss: 3.485972
# Epoch [348 / 500] average loss: 3.484943
# Epoch [349 / 500] average loss: 3.483554
# Epoch [350 / 500] average loss: 3.484494
# Epoch [351 / 500] average loss: 3.485709
# Epoch [352 / 500] average loss: 3.481502
# Epoch [353 / 500] average loss: 3.480705
# Epoch [354 / 500] average loss: 3.484411
# Epoch [355 / 500] average loss: 3.481191
# Epoch [356 / 500] average loss: 3.484910
# Epoch [357 / 500] average loss: 3.490034
# Epoch [358 / 500] average loss: 3.480420
# Epoch [359 / 500] average loss: 3.488633
# Epoch [360 / 500] average loss: 3.482335
# Epoch [361 / 500] average loss: 3.480630
# Epoch [362 / 500] average loss: 3.483808
# Epoch [363 / 500] average loss: 3.483540
# Epoch [364 / 500] average loss: 3.486830
# Epoch [365 / 500] average loss: 3.486994
# Epoch [366 / 500] average loss: 3.483849
# Epoch [367 / 500] average loss: 3.479788
# Epoch [368 / 500] average loss: 3.478534
# Epoch [369 / 500] average loss: 3.477716
# Epoch [370 / 500] average loss: 3.480814
# Epoch [371 / 500] average loss: 3.483300
# Epoch [372 / 500] average loss: 3.483367
# Epoch [373 / 500] average loss: 3.483588
# Epoch [374 / 500] average loss: 3.482881
# Epoch [375 / 500] average loss: 3.489626
# Epoch [376 / 500] average loss: 3.483608
# Epoch [377 / 500] average loss: 3.489212
# Epoch [378 / 500] average loss: 3.484755
# Epoch [379 / 500] average loss: 3.481168
# Epoch [380 / 500] average loss: 3.483059
# Epoch [381 / 500] average loss: 3.487313
# Epoch [382 / 500] average loss: 3.483127
# Epoch [383 / 500] average loss: 3.484224
# Epoch [384 / 500] average loss: 3.486742
# Epoch [385 / 500] average loss: 3.480284
# Epoch [386 / 500] average loss: 3.483897
# Epoch [387 / 500] average loss: 3.482868
# Epoch [388 / 500] average loss: 3.486576
# Epoch [389 / 500] average loss: 3.485835
# Epoch [390 / 500] average loss: 3.486039
# Epoch [391 / 500] average loss: 3.482503
# Epoch [392 / 500] average loss: 3.479981
# Epoch [393 / 500] average loss: 3.477057
# Epoch [394 / 500] average loss: 3.488002
# Epoch [395 / 500] average loss: 3.483671
# Epoch [396 / 500] average loss: 3.483975
# Epoch [397 / 500] average loss: 3.481417
# Epoch [398 / 500] average loss: 3.486320
# Epoch [399 / 500] average loss: 3.483662
# Epoch [400 / 500] average loss: 3.484162
# Epoch [401 / 500] average loss: 3.486371
# Epoch [402 / 500] average loss: 3.484329
# Epoch [403 / 500] average loss: 3.480993
# Epoch [404 / 500] average loss: 3.482475
# Epoch [405 / 500] average loss: 3.480536
# Epoch [406 / 500] average loss: 3.483107
# Epoch [407 / 500] average loss: 3.477901
# Epoch [408 / 500] average loss: 3.486045
# Epoch [409 / 500] average loss: 3.481052
# Epoch [410 / 500] average loss: 3.489034
# Epoch [411 / 500] average loss: 3.479826
# Epoch [412 / 500] average loss: 3.483731
# Epoch [413 / 500] average loss: 3.479947
# Epoch [414 / 500] average loss: 3.488205
# Epoch [415 / 500] average loss: 3.482322
# Epoch [416 / 500] average loss: 3.485060
# Epoch [417 / 500] average loss: 3.482186
# Epoch [418 / 500] average loss: 3.482924
# Epoch [419 / 500] average loss: 3.483619
# Epoch [420 / 500] average loss: 3.485049
# Epoch [421 / 500] average loss: 3.483232
# Epoch [422 / 500] average loss: 3.480690
# Epoch [423 / 500] average loss: 3.481406
# Epoch [424 / 500] average loss: 3.485642
# Epoch [425 / 500] average loss: 3.481554
# Epoch [426 / 500] average loss: 3.485291
# Epoch [427 / 500] average loss: 3.486458
# Epoch [428 / 500] average loss: 3.485017
# Epoch [429 / 500] average loss: 3.482532
# Epoch [430 / 500] average loss: 3.486216
# Epoch [431 / 500] average loss: 3.484826
# Epoch [432 / 500] average loss: 3.485309
# Epoch [433 / 500] average loss: 3.487096
# Epoch [434 / 500] average loss: 3.483173
# Epoch [435 / 500] average loss: 3.482209
# Epoch [436 / 500] average loss: 3.486153
# Epoch [437 / 500] average loss: 3.483183
# Epoch [438 / 500] average loss: 3.485281
# Epoch [439 / 500] average loss: 3.489581
# Epoch [440 / 500] average loss: 3.489280
# Epoch [441 / 500] average loss: 3.483708
# Epoch [442 / 500] average loss: 3.483315
# Epoch [443 / 500] average loss: 3.478321
# Epoch [444 / 500] average loss: 3.488041
# Epoch [445 / 500] average loss: 3.482248
# Epoch [446 / 500] average loss: 3.481367
# Epoch [447 / 500] average loss: 3.481929
# Epoch [448 / 500] average loss: 3.483965
# Epoch [449 / 500] average loss: 3.494949
# Epoch [450 / 500] average loss: 3.484297
# Epoch [451 / 500] average loss: 3.483982
# Epoch [452 / 500] average loss: 3.486176
# Epoch [453 / 500] average loss: 3.482598
# Epoch [454 / 500] average loss: 3.481414
# Epoch [455 / 500] average loss: 3.483637
# Epoch [456 / 500] average loss: 3.479651
# Epoch [457 / 500] average loss: 3.484010
# Epoch [458 / 500] average loss: 3.480824
# Epoch [459 / 500] average loss: 3.481475
# Epoch [460 / 500] average loss: 3.491355
# Epoch [461 / 500] average loss: 3.480141
# Epoch [462 / 500] average loss: 3.482792
# Epoch [463 / 500] average loss: 3.480611
# Epoch [464 / 500] average loss: 3.483372
# Epoch [465 / 500] average loss: 3.483917
# Epoch [466 / 500] average loss: 3.481464
# Epoch [467 / 500] average loss: 3.480446
# Epoch [468 / 500] average loss: 3.487236
# Epoch [469 / 500] average loss: 3.483638
# Epoch [470 / 500] average loss: 3.484581
# Epoch [471 / 500] average loss: 3.487044
# Epoch [472 / 500] average loss: 3.478694
# Epoch [473 / 500] average loss: 3.484820
# Epoch [474 / 500] average loss: 3.482505
# Epoch [475 / 500] average loss: 3.483364
# Epoch [476 / 500] average loss: 3.481937
# Epoch [477 / 500] average loss: 3.483455
# Epoch [478 / 500] average loss: 3.483099
# Epoch [479 / 500] average loss: 3.485211
# Epoch [480 / 500] average loss: 3.485267
# Epoch [481 / 500] average loss: 3.481193
# Epoch [482 / 500] average loss: 3.484236
# Epoch [483 / 500] average loss: 3.483642
# Epoch [484 / 500] average loss: 3.479728
# Epoch [485 / 500] average loss: 3.477929
# Epoch [486 / 500] average loss: 3.488294
# Epoch [487 / 500] average loss: 3.483098
# Epoch [488 / 500] average loss: 3.485736
# Epoch [489 / 500] average loss: 3.488527
# Epoch [490 / 500] average loss: 3.488687
# Epoch [491 / 500] average loss: 3.485346
# Epoch [492 / 500] average loss: 3.487113
# Epoch [493 / 500] average loss: 3.482371
# Epoch [494 / 500] average loss: 3.482856
# Epoch [495 / 500] average loss: 3.482661
# Epoch [496 / 500] average loss: 3.483869
# Epoch [497 / 500] average loss: 3.480376
# Epoch [498 / 500] average loss: 3.482741
# Epoch [499 / 500] average loss: 3.489075
# Epoch [500 / 500] average loss: 3.481944

# %%
c2c_latent_dims = 3
c2c_capacity = 4
c2c_variational_beta = 1
label_size = 2  # Assuming two classes

# %%
class c2c_Encoder(nn.Module):
    def __init__(self):
        super(c2c_Encoder, self).__init__()
        self.fc1 = nn.Linear(in_features=latent_dims + label_size, out_features=c2c_capacity)
        self.fc_mu = nn.Linear(in_features=c2c_capacity, out_features=c2c_latent_dims)
        self.fc_logvar = nn.Linear(in_features=c2c_capacity, out_features=c2c_latent_dims)
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x_mu = self.fc_mu(x)
        x_logvar = self.fc_logvar(x)
        return x_mu, x_logvar

class c2c_Decoder(nn.Module):
    def __init__(self):
        super(c2c_Decoder, self).__init__()
        self.fc2 = nn.Linear(in_features=c2c_latent_dims + label_size, out_features=c2c_capacity)
        self.fc1 = nn.Linear(in_features=c2c_capacity, out_features=latent_dims)
            
    def forward(self, x):
        x = self.fc2(x)
        x = self.fc1(x)
        return x
    
class c2c_VariationalAutoencoder(nn.Module):
    def __init__(self):
        super(c2c_VariationalAutoencoder, self).__init__()
        self.encoder = c2c_Encoder()
        self.decoder = c2c_Decoder()
    
    def forward(self, x):
        x,label = torch.split(x,(latent_dims,label_size),dim = 1)
        c2c_latent_mu, c2c_latent_logvar = self.encoder(torch.cat((x,label), dim=1))
        c2c_latent = self.latent_sample(c2c_latent_mu, c2c_latent_logvar)
        x_recon = self.decoder(torch.cat((c2c_latent,label), dim=1))
        return x_recon, c2c_latent_mu, c2c_latent_logvar
    
    def latent_sample(self, mu, logvar):
        if self.training:
            std = logvar.mul(0.5).exp_()
            eps = torch.empty_like(std).normal_()
            return eps.mul(std).add_(mu)
        else:
            return mu
    
def c2c_vae_loss(recon_x, x, mu, logvar):
    recon_loss = F.mse_loss(recon_x.view(-1, latent_dims), x.view(-1, latent_dims), reduction='sum')
    
    kldivergence = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    
    return recon_loss + c2c_variational_beta * kldivergence

# %%
print(device)
c2c_vae = c2c_VariationalAutoencoder()
c2c_vae = c2c_vae.to(device)

optimizer = torch.optim.Adam(params=c2c_vae.parameters(), lr=1e-3, weight_decay=1e-5)

train_loss_avg = []

train_c2c_vae = True

if train_c2c_vae == False:
    filename = 'blood_alcohol_c2c.pth'
    c2c_vae.load_state_dict(torch.load(filename))
    c2c_vae.eval()
    print('done')
else:
    for epoch in range(num_epochs):
        c2c_vae.train()
        train_loss_avg.append(0)
        num_batches = 0

        for i in range(dl_batch_size):

            x_batch1, labels1 = next(iter(train_dataloader))
            x_batch2, labels2 = next(iter(train_dataloader))

            x_batch1 = x_batch1.to(device)
            x_batch_recon1, latent_mu1, latent_logvar1 = vae(x_batch1)

            x_batch2 = x_batch2.to(device)
            x_batch_recon2, latent_mu2, latent_logvar2 = vae(x_batch2) 

            latent_diff = latent_mu1 - latent_mu2 
            label_diff = torch.cat((labels1.unsqueeze(1), labels2.unsqueeze(1)), dim=1)
            #print(label_diff)

            latent_diff = latent_diff.to(device)
            label_diff = label_diff.float().to(device)

            c2c_input = torch.cat((latent_diff,label_diff), dim=1)
            c2c_input = c2c_input.to(device)

            c2c_recon, c2c_latent_mu, c2c_latent_logvar = c2c_vae(c2c_input)
            loss = c2c_vae_loss(c2c_recon, latent_diff.detach(), c2c_latent_mu, c2c_latent_logvar)
            optimizer.zero_grad()
            loss.backward()

            optimizer.step()
            train_loss_avg[-1] += loss.item()
            num_batches += 1

        train_loss_avg[-1] /= num_batches
        print('Epoch [%d / %d] average reconstruction error: %f' % (epoch + 1, num_epochs, train_loss_avg[-1]))

    # Save the model
    model_name = data+'_c2c.pth'
    torch.save(c2c_vae.state_dict(), model_name)
# Out:
# mps
# Epoch [1 / 500] average reconstruction error: 35.686619
# Epoch [2 / 500] average reconstruction error: 24.619245
# Epoch [3 / 500] average reconstruction error: 17.011734
# Epoch [4 / 500] average reconstruction error: 12.343631
# Epoch [5 / 500] average reconstruction error: 8.651665
# Epoch [6 / 500] average reconstruction error: 5.989851
# Epoch [7 / 500] average reconstruction error: 3.629751
# Epoch [8 / 500] average reconstruction error: 2.374440
# Epoch [9 / 500] average reconstruction error: 1.467598
# Epoch [10 / 500] average reconstruction error: 0.934400
# Epoch [11 / 500] average reconstruction error: 0.664530
# Epoch [12 / 500] average reconstruction error: 0.526600
# Epoch [13 / 500] average reconstruction error: 0.403222
# Epoch [14 / 500] average reconstruction error: 0.332474
# Epoch [15 / 500] average reconstruction error: 0.262767
# Epoch [16 / 500] average reconstruction error: 0.228804
# Epoch [17 / 500] average reconstruction error: 0.184004
# Epoch [18 / 500] average reconstruction error: 0.162620
# Epoch [19 / 500] average reconstruction error: 0.136595
# Epoch [20 / 500] average reconstruction error: 0.118537
# Epoch [21 / 500] average reconstruction error: 0.101435
# Epoch [22 / 500] average reconstruction error: 0.087790
# Epoch [23 / 500] average reconstruction error: 0.079246
# Epoch [24 / 500] average reconstruction error: 0.070232
# Epoch [25 / 500] average reconstruction error: 0.061806
# Epoch [26 / 500] average reconstruction error: 0.056030
# Epoch [27 / 500] average reconstruction error: 0.050961
# Epoch [28 / 500] average reconstruction error: 0.045533
# Epoch [29 / 500] average reconstruction error: 0.039822
# Epoch [30 / 500] average reconstruction error: 0.038334
# Epoch [31 / 500] average reconstruction error: 0.035239
# Epoch [32 / 500] average reconstruction error: 0.032166
# Epoch [33 / 500] average reconstruction error: 0.029475
# Epoch [34 / 500] average reconstruction error: 0.030485
# Epoch [35 / 500] average reconstruction error: 0.026685
# Epoch [36 / 500] average reconstruction error: 0.024621
# Epoch [37 / 500] average reconstruction error: 0.022138
# Epoch [38 / 500] average reconstruction error: 0.021700
# Epoch [39 / 500] average reconstruction error: 0.019882
# Epoch [40 / 500] average reconstruction error: 0.018961
# Epoch [41 / 500] average reconstruction error: 0.017774
# Epoch [42 / 500] average reconstruction error: 0.015845
# Epoch [43 / 500] average reconstruction error: 0.015733
# Epoch [44 / 500] average reconstruction error: 0.014198
# Epoch [45 / 500] average reconstruction error: 0.013506
# Epoch [46 / 500] average reconstruction error: 0.012630
# Epoch [47 / 500] average reconstruction error: 0.012069
# Epoch [48 / 500] average reconstruction error: 0.012089
# Epoch [49 / 500] average reconstruction error: 0.010232
# Epoch [50 / 500] average reconstruction error: 0.009971
# Epoch [51 / 500] average reconstruction error: 0.009598
# Epoch [52 / 500] average reconstruction error: 0.009522
# Epoch [53 / 500] average reconstruction error: 0.008858
# Epoch [54 / 500] average reconstruction error: 0.007891
# Epoch [55 / 500] average reconstruction error: 0.007947
# Epoch [56 / 500] average reconstruction error: 0.007251
# Epoch [57 / 500] average reconstruction error: 0.006910
# Epoch [58 / 500] average reconstruction error: 0.006437
# Epoch [59 / 500] average reconstruction error: 0.005963
# Epoch [60 / 500] average reconstruction error: 0.005802
# Epoch [61 / 500] average reconstruction error: 0.005261
# Epoch [62 / 500] average reconstruction error: 0.005070
# Epoch [63 / 500] average reconstruction error: 0.004789
# Epoch [64 / 500] average reconstruction error: 0.004441
# Epoch [65 / 500] average reconstruction error: 0.004059
# Epoch [66 / 500] average reconstruction error: 0.003997
# Epoch [67 / 500] average reconstruction error: 0.003757
# Epoch [68 / 500] average reconstruction error: 0.003702
# Epoch [69 / 500] average reconstruction error: 0.003472
# Epoch [70 / 500] average reconstruction error: 0.003391
# Epoch [71 / 500] average reconstruction error: 0.003193
# Epoch [72 / 500] average reconstruction error: 0.002874
# Epoch [73 / 500] average reconstruction error: 0.002676
# Epoch [74 / 500] average reconstruction error: 0.002562
# Epoch [75 / 500] average reconstruction error: 0.002436
# Epoch [76 / 500] average reconstruction error: 0.002285
# Epoch [77 / 500] average reconstruction error: 0.002148
# Epoch [78 / 500] average reconstruction error: 0.002037
# Epoch [79 / 500] average reconstruction error: 0.001915
# Epoch [80 / 500] average reconstruction error: 0.001863
# Epoch [81 / 500] average reconstruction error: 0.001704
# Epoch [82 / 500] average reconstruction error: 0.001553
# Epoch [83 / 500] average reconstruction error: 0.001550
# Epoch [84 / 500] average reconstruction error: 0.001482
# Epoch [85 / 500] average reconstruction error: 0.001347
# Epoch [86 / 500] average reconstruction error: 0.001221
# Epoch [87 / 500] average reconstruction error: 0.001181
# Epoch [88 / 500] average reconstruction error: 0.001093
# Epoch [89 / 500] average reconstruction error: 0.001062
# Epoch [90 / 500] average reconstruction error: 0.001021
# Epoch [91 / 500] average reconstruction error: 0.001008
# Epoch [92 / 500] average reconstruction error: 0.000846
# Epoch [93 / 500] average reconstruction error: 0.000863
# Epoch [94 / 500] average reconstruction error: 0.000784
# Epoch [95 / 500] average reconstruction error: 0.000772
# Epoch [96 / 500] average reconstruction error: 0.000716
# Epoch [97 / 500] average reconstruction error: 0.000656
# Epoch [98 / 500] average reconstruction error: 0.000618
# Epoch [99 / 500] average reconstruction error: 0.000630
# Epoch [100 / 500] average reconstruction error: 0.000565
# Epoch [101 / 500] average reconstruction error: 0.000553
# Epoch [102 / 500] average reconstruction error: 0.000496
# Epoch [103 / 500] average reconstruction error: 0.000484
# Epoch [104 / 500] average reconstruction error: 0.000468
# Epoch [105 / 500] average reconstruction error: 0.000417
# Epoch [106 / 500] average reconstruction error: 0.000420
# Epoch [107 / 500] average reconstruction error: 0.000379
# Epoch [108 / 500] average reconstruction error: 0.000382
# Epoch [109 / 500] average reconstruction error: 0.000346
# Epoch [110 / 500] average reconstruction error: 0.000340
# Epoch [111 / 500] average reconstruction error: 0.000317
# Epoch [112 / 500] average reconstruction error: 0.000319
# Epoch [113 / 500] average reconstruction error: 0.000300
# Epoch [114 / 500] average reconstruction error: 0.000284
# Epoch [115 / 500] average reconstruction error: 0.000271
# Epoch [116 / 500] average reconstruction error: 0.000265
# Epoch [117 / 500] average reconstruction error: 0.000257
# Epoch [118 / 500] average reconstruction error: 0.000242
# Epoch [119 / 500] average reconstruction error: 0.000241
# Epoch [120 / 500] average reconstruction error: 0.000229
# Epoch [121 / 500] average reconstruction error: 0.000229
# Epoch [122 / 500] average reconstruction error: 0.000213
# Epoch [123 / 500] average reconstruction error: 0.000211
# Epoch [124 / 500] average reconstruction error: 0.000218
# Epoch [125 / 500] average reconstruction error: 0.000199
# Epoch [126 / 500] average reconstruction error: 0.000192
# Epoch [127 / 500] average reconstruction error: 0.000199
# Epoch [128 / 500] average reconstruction error: 0.000186
# Epoch [129 / 500] average reconstruction error: 0.000185
# Epoch [130 / 500] average reconstruction error: 0.000186
# Epoch [131 / 500] average reconstruction error: 0.000175
# Epoch [132 / 500] average reconstruction error: 0.000185
# Epoch [133 / 500] average reconstruction error: 0.000173
# Epoch [134 / 500] average reconstruction error: 0.000182
# Epoch [135 / 500] average reconstruction error: 0.000175
# Epoch [136 / 500] average reconstruction error: 0.000178
# Epoch [137 / 500] average reconstruction error: 0.000171
# Epoch [138 / 500] average reconstruction error: 0.000180
# Epoch [139 / 500] average reconstruction error: 0.000160
# Epoch [140 / 500] average reconstruction error: 0.000171
# Epoch [141 / 500] average reconstruction error: 0.000164
# Epoch [142 / 500] average reconstruction error: 0.000162
# Epoch [143 / 500] average reconstruction error: 0.000168
# Epoch [144 / 500] average reconstruction error: 0.000163
# Epoch [145 / 500] average reconstruction error: 0.000165
# Epoch [146 / 500] average reconstruction error: 0.000159
# Epoch [147 / 500] average reconstruction error: 0.000175
# Epoch [148 / 500] average reconstruction error: 0.000169
# Epoch [149 / 500] average reconstruction error: 0.000159
# Epoch [150 / 500] average reconstruction error: 0.000168
# Epoch [151 / 500] average reconstruction error: 0.000166
# Epoch [152 / 500] average reconstruction error: 0.000156
# Epoch [153 / 500] average reconstruction error: 0.000158
# Epoch [154 / 500] average reconstruction error: 0.000155
# Epoch [155 / 500] average reconstruction error: 0.000161
# Epoch [156 / 500] average reconstruction error: 0.000166
# Epoch [157 / 500] average reconstruction error: 0.000156
# Epoch [158 / 500] average reconstruction error: 0.000177
# Epoch [159 / 500] average reconstruction error: 0.000164
# Epoch [160 / 500] average reconstruction error: 0.000164
# Epoch [161 / 500] average reconstruction error: 0.000162
# Epoch [162 / 500] average reconstruction error: 0.000159
# Epoch [163 / 500] average reconstruction error: 0.000175
# Epoch [164 / 500] average reconstruction error: 0.000154
# Epoch [165 / 500] average reconstruction error: 0.000168
# Epoch [166 / 500] average reconstruction error: 0.000175
# Epoch [167 / 500] average reconstruction error: 0.000157
# Epoch [168 / 500] average reconstruction error: 0.000161
# Epoch [169 / 500] average reconstruction error: 0.000166
# Epoch [170 / 500] average reconstruction error: 0.000164
# Epoch [171 / 500] average reconstruction error: 0.000168
# Epoch [172 / 500] average reconstruction error: 0.000161
# Epoch [173 / 500] average reconstruction error: 0.000169
# Epoch [174 / 500] average reconstruction error: 0.000161
# Epoch [175 / 500] average reconstruction error: 0.000163
# Epoch [176 / 500] average reconstruction error: 0.000162
# Epoch [177 / 500] average reconstruction error: 0.000169
# Epoch [178 / 500] average reconstruction error: 0.000169
# Epoch [179 / 500] average reconstruction error: 0.000160
# Epoch [180 / 500] average reconstruction error: 0.000173
# Epoch [181 / 500] average reconstruction error: 0.000158
# Epoch [182 / 500] average reconstruction error: 0.000166
# Epoch [183 / 500] average reconstruction error: 0.000161
# Epoch [184 / 500] average reconstruction error: 0.000164
# Epoch [185 / 500] average reconstruction error: 0.000163
# Epoch [186 / 500] average reconstruction error: 0.000163
# Epoch [187 / 500] average reconstruction error: 0.000178
# Epoch [188 / 500] average reconstruction error: 0.000159
# Epoch [189 / 500] average reconstruction error: 0.000160
# Epoch [190 / 500] average reconstruction error: 0.000160
# Epoch [191 / 500] average reconstruction error: 0.000175
# Epoch [192 / 500] average reconstruction error: 0.000173
# Epoch [193 / 500] average reconstruction error: 0.000170
# Epoch [194 / 500] average reconstruction error: 0.000156
# Epoch [195 / 500] average reconstruction error: 0.000173
# Epoch [196 / 500] average reconstruction error: 0.000169
# Epoch [197 / 500] average reconstruction error: 0.000162
# Epoch [198 / 500] average reconstruction error: 0.000170
# Epoch [199 / 500] average reconstruction error: 0.000172
# Epoch [200 / 500] average reconstruction error: 0.000167
# Epoch [201 / 500] average reconstruction error: 0.000163
# Epoch [202 / 500] average reconstruction error: 0.000159
# Epoch [203 / 500] average reconstruction error: 0.000174
# Epoch [204 / 500] average reconstruction error: 0.000170
# Epoch [205 / 500] average reconstruction error: 0.000165
# Epoch [206 / 500] average reconstruction error: 0.000171
# Epoch [207 / 500] average reconstruction error: 0.000171
# Epoch [208 / 500] average reconstruction error: 0.000174
# Epoch [209 / 500] average reconstruction error: 0.000166
# Epoch [210 / 500] average reconstruction error: 0.000169
# Epoch [211 / 500] average reconstruction error: 0.000180
# Epoch [212 / 500] average reconstruction error: 0.000176
# Epoch [213 / 500] average reconstruction error: 0.000171
# Epoch [214 / 500] average reconstruction error: 0.000166
# Epoch [215 / 500] average reconstruction error: 0.000178
# Epoch [216 / 500] average reconstruction error: 0.000163
# Epoch [217 / 500] average reconstruction error: 0.000164
# Epoch [218 / 500] average reconstruction error: 0.000172
# Epoch [219 / 500] average reconstruction error: 0.000168
# Epoch [220 / 500] average reconstruction error: 0.000170
# Epoch [221 / 500] average reconstruction error: 0.000166
# Epoch [222 / 500] average reconstruction error: 0.000174
# Epoch [223 / 500] average reconstruction error: 0.000168
# Epoch [224 / 500] average reconstruction error: 0.000172
# Epoch [225 / 500] average reconstruction error: 0.000162
# Epoch [226 / 500] average reconstruction error: 0.000164
# Epoch [227 / 500] average reconstruction error: 0.000170
# Epoch [228 / 500] average reconstruction error: 0.000162
# Epoch [229 / 500] average reconstruction error: 0.000184
# Epoch [230 / 500] average reconstruction error: 0.000165
# Epoch [231 / 500] average reconstruction error: 0.000165
# Epoch [232 / 500] average reconstruction error: 0.000168
# Epoch [233 / 500] average reconstruction error: 0.000168
# Epoch [234 / 500] average reconstruction error: 0.000181
# Epoch [235 / 500] average reconstruction error: 0.000169
# Epoch [236 / 500] average reconstruction error: 0.000170
# Epoch [237 / 500] average reconstruction error: 0.000163
# Epoch [238 / 500] average reconstruction error: 0.000176
# Epoch [239 / 500] average reconstruction error: 0.000166
# Epoch [240 / 500] average reconstruction error: 0.000169
# Epoch [241 / 500] average reconstruction error: 0.000179
# Epoch [242 / 500] average reconstruction error: 0.000164
# Epoch [243 / 500] average reconstruction error: 0.000174
# Epoch [244 / 500] average reconstruction error: 0.000178
# Epoch [245 / 500] average reconstruction error: 0.000180
# Epoch [246 / 500] average reconstruction error: 0.000170
# Epoch [247 / 500] average reconstruction error: 0.000169
# Epoch [248 / 500] average reconstruction error: 0.000170
# Epoch [249 / 500] average reconstruction error: 0.000182
# Epoch [250 / 500] average reconstruction error: 0.000177
# Epoch [251 / 500] average reconstruction error: 0.000169
# Epoch [252 / 500] average reconstruction error: 0.000174
# Epoch [253 / 500] average reconstruction error: 0.000180
# Epoch [254 / 500] average reconstruction error: 0.000188
# Epoch [255 / 500] average reconstruction error: 0.000183
# Epoch [256 / 500] average reconstruction error: 0.000175
# Epoch [257 / 500] average reconstruction error: 0.000174
# Epoch [258 / 500] average reconstruction error: 0.000171
# Epoch [259 / 500] average reconstruction error: 0.000170
# Epoch [260 / 500] average reconstruction error: 0.000174
# Epoch [261 / 500] average reconstruction error: 0.000185
# Epoch [262 / 500] average reconstruction error: 0.000173
# Epoch [263 / 500] average reconstruction error: 0.000175
# Epoch [264 / 500] average reconstruction error: 0.000182
# Epoch [265 / 500] average reconstruction error: 0.000187
# Epoch [266 / 500] average reconstruction error: 0.000190
# Epoch [267 / 500] average reconstruction error: 0.000181
# Epoch [268 / 500] average reconstruction error: 0.000197
# Epoch [269 / 500] average reconstruction error: 0.000176
# Epoch [270 / 500] average reconstruction error: 0.000176
# Epoch [271 / 500] average reconstruction error: 0.000191
# Epoch [272 / 500] average reconstruction error: 0.000176
# Epoch [273 / 500] average reconstruction error: 0.000176
# Epoch [274 / 500] average reconstruction error: 0.000187
# Epoch [275 / 500] average reconstruction error: 0.000187
# Epoch [276 / 500] average reconstruction error: 0.000172
# Epoch [277 / 500] average reconstruction error: 0.000173
# Epoch [278 / 500] average reconstruction error: 0.000172
# Epoch [279 / 500] average reconstruction error: 0.000176
# Epoch [280 / 500] average reconstruction error: 0.000187
# Epoch [281 / 500] average reconstruction error: 0.000183
# Epoch [282 / 500] average reconstruction error: 0.000175
# Epoch [283 / 500] average reconstruction error: 0.000184
# Epoch [284 / 500] average reconstruction error: 0.000183
# Epoch [285 / 500] average reconstruction error: 0.000170
# Epoch [286 / 500] average reconstruction error: 0.000179
# Epoch [287 / 500] average reconstruction error: 0.000175
# Epoch [288 / 500] average reconstruction error: 0.000188
# Epoch [289 / 500] average reconstruction error: 0.000187
# Epoch [290 / 500] average reconstruction error: 0.000202
# Epoch [291 / 500] average reconstruction error: 0.000201
# Epoch [292 / 500] average reconstruction error: 0.000180
# Epoch [293 / 500] average reconstruction error: 0.000179
# Epoch [294 / 500] average reconstruction error: 0.000177
# Epoch [295 / 500] average reconstruction error: 0.000183
# Epoch [296 / 500] average reconstruction error: 0.000172
# Epoch [297 / 500] average reconstruction error: 0.000177
# Epoch [298 / 500] average reconstruction error: 0.000199
# Epoch [299 / 500] average reconstruction error: 0.000187
# Epoch [300 / 500] average reconstruction error: 0.000185
# Epoch [301 / 500] average reconstruction error: 0.000198
# Epoch [302 / 500] average reconstruction error: 0.000181
# Epoch [303 / 500] average reconstruction error: 0.000202
# Epoch [304 / 500] average reconstruction error: 0.000194
# Epoch [305 / 500] average reconstruction error: 0.000226
# Epoch [306 / 500] average reconstruction error: 0.000202
# Epoch [307 / 500] average reconstruction error: 0.000197
# Epoch [308 / 500] average reconstruction error: 0.000195
# Epoch [309 / 500] average reconstruction error: 0.000189
# Epoch [310 / 500] average reconstruction error: 0.000188
# Epoch [311 / 500] average reconstruction error: 0.000180
# Epoch [312 / 500] average reconstruction error: 0.000181
# Epoch [313 / 500] average reconstruction error: 0.000182
# Epoch [314 / 500] average reconstruction error: 0.000181
# Epoch [315 / 500] average reconstruction error: 0.000184
# Epoch [316 / 500] average reconstruction error: 0.000182
# Epoch [317 / 500] average reconstruction error: 0.000180
# Epoch [318 / 500] average reconstruction error: 0.000219
# Epoch [319 / 500] average reconstruction error: 0.000207
# Epoch [320 / 500] average reconstruction error: 0.000203
# Epoch [321 / 500] average reconstruction error: 0.000182
# Epoch [322 / 500] average reconstruction error: 0.000218
# Epoch [323 / 500] average reconstruction error: 0.000195
# Epoch [324 / 500] average reconstruction error: 0.000212
# Epoch [325 / 500] average reconstruction error: 0.000204
# Epoch [326 / 500] average reconstruction error: 0.000199
# Epoch [327 / 500] average reconstruction error: 0.000191
# Epoch [328 / 500] average reconstruction error: 0.000191
# Epoch [329 / 500] average reconstruction error: 0.000203
# Epoch [330 / 500] average reconstruction error: 0.000213
# Epoch [331 / 500] average reconstruction error: 0.000183
# Epoch [332 / 500] average reconstruction error: 0.000182
# Epoch [333 / 500] average reconstruction error: 0.000208
# Epoch [334 / 500] average reconstruction error: 0.000184
# Epoch [335 / 500] average reconstruction error: 0.000216
# Epoch [336 / 500] average reconstruction error: 0.000194
# Epoch [337 / 500] average reconstruction error: 0.000220
# Epoch [338 / 500] average reconstruction error: 0.000198
# Epoch [339 / 500] average reconstruction error: 0.000199
# Epoch [340 / 500] average reconstruction error: 0.000201
# Epoch [341 / 500] average reconstruction error: 0.000197
# Epoch [342 / 500] average reconstruction error: 0.000196
# Epoch [343 / 500] average reconstruction error: 0.000202
# Epoch [344 / 500] average reconstruction error: 0.000193
# Epoch [345 / 500] average reconstruction error: 0.000186
# Epoch [346 / 500] average reconstruction error: 0.000195
# Epoch [347 / 500] average reconstruction error: 0.000182
# Epoch [348 / 500] average reconstruction error: 0.000188
# Epoch [349 / 500] average reconstruction error: 0.000193
# Epoch [350 / 500] average reconstruction error: 0.000209
# Epoch [351 / 500] average reconstruction error: 0.000213
# Epoch [352 / 500] average reconstruction error: 0.000192
# Epoch [353 / 500] average reconstruction error: 0.000199
# Epoch [354 / 500] average reconstruction error: 0.000210
# Epoch [355 / 500] average reconstruction error: 0.000184
# Epoch [356 / 500] average reconstruction error: 0.000191
# Epoch [357 / 500] average reconstruction error: 0.000202
# Epoch [358 / 500] average reconstruction error: 0.000209
# Epoch [359 / 500] average reconstruction error: 0.000202
# Epoch [360 / 500] average reconstruction error: 0.000204
# Epoch [361 / 500] average reconstruction error: 0.000188
# Epoch [362 / 500] average reconstruction error: 0.000201
# Epoch [363 / 500] average reconstruction error: 0.000195
# Epoch [364 / 500] average reconstruction error: 0.000188
# Epoch [365 / 500] average reconstruction error: 0.000201
# Epoch [366 / 500] average reconstruction error: 0.000217
# Epoch [367 / 500] average reconstruction error: 0.000208
# Epoch [368 / 500] average reconstruction error: 0.000215
# Epoch [369 / 500] average reconstruction error: 0.000219
# Epoch [370 / 500] average reconstruction error: 0.000202
# Epoch [371 / 500] average reconstruction error: 0.000193
# Epoch [372 / 500] average reconstruction error: 0.000206
# Epoch [373 / 500] average reconstruction error: 0.000212
# Epoch [374 / 500] average reconstruction error: 0.000198
# Epoch [375 / 500] average reconstruction error: 0.000201
# Epoch [376 / 500] average reconstruction error: 0.000191
# Epoch [377 / 500] average reconstruction error: 0.000184
# Epoch [378 / 500] average reconstruction error: 0.000182
# Epoch [379 / 500] average reconstruction error: 0.000187
# Epoch [380 / 500] average reconstruction error: 0.000196
# Epoch [381 / 500] average reconstruction error: 0.000222
# Epoch [382 / 500] average reconstruction error: 0.000235
# Epoch [383 / 500] average reconstruction error: 0.000223
# Epoch [384 / 500] average reconstruction error: 0.000218
# Epoch [385 / 500] average reconstruction error: 0.000174
# Epoch [386 / 500] average reconstruction error: 0.000206
# Epoch [387 / 500] average reconstruction error: 0.000202
# Epoch [388 / 500] average reconstruction error: 0.000195
# Epoch [389 / 500] average reconstruction error: 0.000216
# Epoch [390 / 500] average reconstruction error: 0.000193
# Epoch [391 / 500] average reconstruction error: 0.000197
# Epoch [392 / 500] average reconstruction error: 0.000212
# Epoch [393 / 500] average reconstruction error: 0.000190
# Epoch [394 / 500] average reconstruction error: 0.000186
# Epoch [395 / 500] average reconstruction error: 0.000195
# Epoch [396 / 500] average reconstruction error: 0.000213
# Epoch [397 / 500] average reconstruction error: 0.000223
# Epoch [398 / 500] average reconstruction error: 0.000218
# Epoch [399 / 500] average reconstruction error: 0.000197
# Epoch [400 / 500] average reconstruction error: 0.000238
# Epoch [401 / 500] average reconstruction error: 0.000212
# Epoch [402 / 500] average reconstruction error: 0.000203
# Epoch [403 / 500] average reconstruction error: 0.000203
# Epoch [404 / 500] average reconstruction error: 0.000201
# Epoch [405 / 500] average reconstruction error: 0.000190
# Epoch [406 / 500] average reconstruction error: 0.000194
# Epoch [407 / 500] average reconstruction error: 0.000203
# Epoch [408 / 500] average reconstruction error: 0.000200
# Epoch [409 / 500] average reconstruction error: 0.000192
# Epoch [410 / 500] average reconstruction error: 0.000194
# Epoch [411 / 500] average reconstruction error: 0.000206
# Epoch [412 / 500] average reconstruction error: 0.000234
# Epoch [413 / 500] average reconstruction error: 0.000200
# Epoch [414 / 500] average reconstruction error: 0.000181
# Epoch [415 / 500] average reconstruction error: 0.000184
# Epoch [416 / 500] average reconstruction error: 0.000190
# Epoch [417 / 500] average reconstruction error: 0.000205
# Epoch [418 / 500] average reconstruction error: 0.000221
# Epoch [419 / 500] average reconstruction error: 0.000199
# Epoch [420 / 500] average reconstruction error: 0.000210
# Epoch [421 / 500] average reconstruction error: 0.000199
# Epoch [422 / 500] average reconstruction error: 0.000213
# Epoch [423 / 500] average reconstruction error: 0.000227
# Epoch [424 / 500] average reconstruction error: 0.000185
# Epoch [425 / 500] average reconstruction error: 0.000188
# Epoch [426 / 500] average reconstruction error: 0.000178
# Epoch [427 / 500] average reconstruction error: 0.000181
# Epoch [428 / 500] average reconstruction error: 0.000207
# Epoch [429 / 500] average reconstruction error: 0.000211
# Epoch [430 / 500] average reconstruction error: 0.000205
# Epoch [431 / 500] average reconstruction error: 0.000206
# Epoch [432 / 500] average reconstruction error: 0.000195
# Epoch [433 / 500] average reconstruction error: 0.000241
# Epoch [434 / 500] average reconstruction error: 0.000224
# Epoch [435 / 500] average reconstruction error: 0.000198
# Epoch [436 / 500] average reconstruction error: 0.000207
# Epoch [437 / 500] average reconstruction error: 0.000232
# Epoch [438 / 500] average reconstruction error: 0.000201
# Epoch [439 / 500] average reconstruction error: 0.000195
# Epoch [440 / 500] average reconstruction error: 0.000182
# Epoch [441 / 500] average reconstruction error: 0.000185
# Epoch [442 / 500] average reconstruction error: 0.000197
# Epoch [443 / 500] average reconstruction error: 0.000215
# Epoch [444 / 500] average reconstruction error: 0.000190
# Epoch [445 / 500] average reconstruction error: 0.000185
# Epoch [446 / 500] average reconstruction error: 0.000181
# Epoch [447 / 500] average reconstruction error: 0.000194
# Epoch [448 / 500] average reconstruction error: 0.000225
# Epoch [449 / 500] average reconstruction error: 0.000210
# Epoch [450 / 500] average reconstruction error: 0.000195
# Epoch [451 / 500] average reconstruction error: 0.000223
# Epoch [452 / 500] average reconstruction error: 0.000192
# Epoch [453 / 500] average reconstruction error: 0.000204
# Epoch [454 / 500] average reconstruction error: 0.000203
# Epoch [455 / 500] average reconstruction error: 0.000202
# Epoch [456 / 500] average reconstruction error: 0.000194
# Epoch [457 / 500] average reconstruction error: 0.000216
# Epoch [458 / 500] average reconstruction error: 0.000199
# Epoch [459 / 500] average reconstruction error: 0.000177
# Epoch [460 / 500] average reconstruction error: 0.000199
# Epoch [461 / 500] average reconstruction error: 0.000191
# Epoch [462 / 500] average reconstruction error: 0.000204
# Epoch [463 / 500] average reconstruction error: 0.000211
# Epoch [464 / 500] average reconstruction error: 0.000254
# Epoch [465 / 500] average reconstruction error: 0.000182
# Epoch [466 / 500] average reconstruction error: 0.000183
# Epoch [467 / 500] average reconstruction error: 0.000201
# Epoch [468 / 500] average reconstruction error: 0.000211
# Epoch [469 / 500] average reconstruction error: 0.000250
# Epoch [470 / 500] average reconstruction error: 0.000195
# Epoch [471 / 500] average reconstruction error: 0.000202
# Epoch [472 / 500] average reconstruction error: 0.000203
# Epoch [473 / 500] average reconstruction error: 0.000199
# Epoch [474 / 500] average reconstruction error: 0.000199
# Epoch [475 / 500] average reconstruction error: 0.000225
# Epoch [476 / 500] average reconstruction error: 0.000231
# Epoch [477 / 500] average reconstruction error: 0.000205
# Epoch [478 / 500] average reconstruction error: 0.000217
# Epoch [479 / 500] average reconstruction error: 0.000254
# Epoch [480 / 500] average reconstruction error: 0.000204
# Epoch [481 / 500] average reconstruction error: 0.000234
# Epoch [482 / 500] average reconstruction error: 0.000197
# Epoch [483 / 500] average reconstruction error: 0.000195
# Epoch [484 / 500] average reconstruction error: 0.000230
# Epoch [485 / 500] average reconstruction error: 0.000187
# Epoch [486 / 500] average reconstruction error: 0.000183
# Epoch [487 / 500] average reconstruction error: 0.000187
# Epoch [488 / 500] average reconstruction error: 0.000187
# Epoch [489 / 500] average reconstruction error: 0.000190
# Epoch [490 / 500] average reconstruction error: 0.000187
# Epoch [491 / 500] average reconstruction error: 0.000196
# Epoch [492 / 500] average reconstruction error: 0.000228
# Epoch [493 / 500] average reconstruction error: 0.000219
# Epoch [494 / 500] average reconstruction error: 0.000207
# Epoch [495 / 500] average reconstruction error: 0.000201
# Epoch [496 / 500] average reconstruction error: 0.000213
# Epoch [497 / 500] average reconstruction error: 0.000206
# Epoch [498 / 500] average reconstruction error: 0.000216
# Epoch [499 / 500] average reconstruction error: 0.000222
# Epoch [500 / 500] average reconstruction error: 0.000212

# %%
def c2c_vae_cfe_v3(label1, label2, query):
    N_guides = 4
    lambd = 0.2
    label_diff = torch.cat((torch.tensor([[label1]]), torch.tensor([[label2]])), dim=1)
    label_diff = label_diff.to(device)

    
    #print(query.to(device))
    with torch.no_grad():
        _, latent_mu1, _ = vae(query.to(device))
    
    for i in range(1):
        #flag = False
        latent_diffs = torch.empty(N_guides,c2c_latent_dims).normal_(mean=0,std=0.5).to(device)
        label_diff_repeated = label_diff.repeat(N_guides, 1)
        c2c_encoding = torch.cat((latent_diffs,label_diff_repeated.float()), dim=1)
        
        with torch.no_grad():
            c2c_recon = c2c_vae.decoder(c2c_encoding)
            recon_from_c2c_recon = vae.decoder(latent_mu1 - c2c_recon).cpu()
        #print(recon_from_c2c_recon.shape)
    
        queries = torch.cat([query]*N_guides,axis=0)
        #print(queries.shape)
        diff = (recon_from_c2c_recon-queries)**2
        #print(torch.sum(diff,axis=2).shape)
        guide_idx = torch.argmin(torch.sum(diff, dim=1))
        #print(recon_from_c2c_recon.shape)
        native_guide = recon_from_c2c_recon[guide_idx,:]
        #guide_latent = (latent_mu1 - c2c_recon)[guide_idx]
        
        with torch.no_grad():
            _, latent_mu2, _ = vae(native_guide.to(device).unsqueeze(0))
            new_latent_mu = (1-lambd)*latent_mu1 + lambd*latent_mu2
            sf = vae.decoder(new_latent_mu)
    
    return sf[0].cpu()

# %%
label1 = 0
label2 = 0

query = torch.tensor([x[0]], dtype=torch.float32)

sf = c2c_vae_cfe_v3(label1, label2, query)
#print(sf)

# %%
sf = sf.numpy()
sf
# Out:
# array([0.6830274 , 0.52631366, 0.3713135 , 0.41656673, 0.44854012],
#       dtype=float32)

# %%
# for categorical idxs, replace the values with the nearest categorical embedding values
cat_embed = {0: {'Female': 0.5046101778656127, 'Male': 0.8299651515151515},
 1: {'No': 0.6450204795204795, 'Yes': 0.6859795204795204}}

# %%
# Function to find the nearest value in the dictionary
def find_nearest_value(index, value):
    values = cat_embed[index].values()
    nearest_value = min(values, key=lambda x: abs(x - value))
    return nearest_value

# %%
# Replace values in the numpy array
cat_feats_idx = [0, 1]
for i in (cat_feats_idx):
    value = sf[i]
    nearest_value = find_nearest_value(i, value)
    sf[i] = nearest_value

# %%
sf
# Out:
# array([0.8299652 , 0.6450205 , 0.3713135 , 0.41656673, 0.44854012],
#       dtype=float32)

# %%
x[0]
# Out:
# array([0.82996515, 0.64502048, 0.27272727, 0.51315789, 0.69172932])

# %%
y[0]
# Out:
# 0
